# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to ensure it is sufficient:
len(cities)
# Out:
# 790

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
                
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
len(city_data)
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | tiznit
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | hvide sande
# Processing Record 7 of Set 1 | santa cruz
# Processing Record 8 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 9 of Set 1 | vila velha
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | marrakesh
# Processing Record 17 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 1 | port macquarie
# Processing Record 19 of Set 1 | sola
# Processing Record 20 of Set 1 | nelson bay
# Processing Record 21 of Set 1 | nkhotakota
# Processing Record 22 of Set 1 | waw
# Processing Record 23 of Set 1 | labuhan
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | camana
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | vila
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | marawi
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | homer
# Processing Record 36 of Set 1 | sorland
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | sur
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | vargashi
# Processing Record 41 of Set 1 | fort saint james
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | udayagiri
# Processing Record 44 of Set 1 | vestmannaeyjar
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | axim
# Processing Record 47 of Set 1 | bedele
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 1 | kutum
# Processing Record 1 of Set 2 | yining
# Processing Record 2 of Set 2 | kariba
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | saint-augustin
# Processing Record 7 of Set 2 | aykhal
# Processing Record 8 of Set 2 | brodokalmak
# Processing Record 9 of Set 2 | tripoli
# Processing Record 10 of Set 2 | zhigansk
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | buraydah
# Processing Record 14 of Set 2 | mogadishu
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | vostok
# Processing Record 17 of Set 2 | balabac
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | talaya
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | cocachacra
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | vestmanna
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | la libertad
# Processing Record 30 of Set 2 | san andres
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 2 | zemio
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | zhob
# Processing Record 36 of Set 2 | cururupu
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | leh
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | yatou
# Processing Record 41 of Set 2 | traverse city
# Processing Record 42 of Set 2 | tutoia
# Processing Record 43 of Set 2 | santa maria
# Processing Record 44 of Set 2 | bay roberts
# Processing Record 45 of Set 2 | wangaratta
# Processing Record 46 of Set 2 | lidkoping
# Processing Record 47 of Set 2 | vredendal
# Processing Record 48 of Set 2 | panaba
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | mao
# Processing Record 1 of Set 3 | richards bay
# Processing Record 2 of Set 3 | trelew
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | oranjestad
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | yeppoon
# Processing Record 7 of Set 3 | kununurra
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | alice springs
# Processing Record 12 of Set 3 | nantucket
# Processing Record 13 of Set 3 | vicuna
# Processing Record 14 of Set 3 | moanda
# Processing Record 15 of Set 3 | ayan
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 3 | kinshasa
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | gat
# Processing Record 25 of Set 3 | magole
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | milkovo
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | luau
# Processing Record 32 of Set 3 | beloha
# Processing Record 33 of Set 3 | talnakh
# Processing Record 34 of Set 3 | chifeng
# Processing Record 35 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | gombong
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | evanston
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | patrocinio
# Processing Record 43 of Set 3 | alta floresta
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | fernley
# Processing Record 47 of Set 3 | sterling
# Processing Record 48 of Set 3 | lumby
# Processing Record 49 of Set 3 | qostanay
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | qesarya
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | van
# Processing Record 6 of Set 4 | teguldet
# Processing Record 7 of Set 4 | paamiut
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | nassau
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | asfi
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | torrington
# Processing Record 16 of Set 4 | zambezi
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | pakala
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | husavik
# Processing Record 23 of Set 4 | dukat
# Processing Record 24 of Set 4 | labuan
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | lorengau
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | magistralnyy
# Processing Record 29 of Set 4 | houma
# Processing Record 30 of Set 4 | vanderhoof
# Processing Record 31 of Set 4 | melilla
# Processing Record 32 of Set 4 | capreol
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | jumilla
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | tautira
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | yinchuan
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | bage
# Processing Record 42 of Set 4 | inyonga
# Processing Record 43 of Set 4 | carutapera
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | sambava
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | ust-maya
# Processing Record 50 of Set 4 | deputatskiy
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | trairi
# Processing Record 3 of Set 5 | manuk mangkaw
# Processing Record 4 of Set 5 | olafsvik
# Processing Record 5 of Set 5 | taoudenni
# Processing Record 6 of Set 5 | hovd
# Processing Record 7 of Set 5 | acapulco
# Processing Record 8 of Set 5 | gudibanda
# Processing Record 9 of Set 5 | sjenica
# Processing Record 10 of Set 5 | indiana
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | moron
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | gigmoto
# Processing Record 15 of Set 5 | vilyuysk
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | igrim
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | tagusao
# Processing Record 20 of Set 5 | general roca
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | new norfolk
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | asmara
# Processing Record 25 of Set 5 | yerbogachen
# Processing Record 26 of Set 5 | kankon
# Processing Record 27 of Set 5 | otradnyy
# Processing Record 28 of Set 5 | potam
# Processing Record 29 of Set 5 | cap malheureux
# Processing Record 30 of Set 5 | honiara
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | campbell river
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | lugovoy
# Processing Record 35 of Set 5 | mednogorsk
# Processing Record 36 of Set 5 | xai-xai
# Processing Record 37 of Set 5 | oranjemund
# Processing Record 38 of Set 5 | komsomolskiy
# Processing Record 39 of Set 5 | harrison
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | gillette
# Processing Record 42 of Set 5 | quzhou
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | catamarca
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | pedana
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | tual
# Processing Record 1 of Set 6 | kembe
# Processing Record 2 of Set 6 | teya
# Processing Record 3 of Set 6 | joshimath
# Processing Record 4 of Set 6 | derzhavinsk
# Processing Record 5 of Set 6 | aba
# Processing Record 6 of Set 6 | gamba
# Processing Record 7 of Set 6 | antofagasta
# Processing Record 8 of Set 6 | mapiripan
# Processing Record 9 of Set 6 | la ronge
# Processing Record 10 of Set 6 | kendari
# Processing Record 11 of Set 6 | thinadhoo
# Processing Record 12 of Set 6 | porto novo
# Processing Record 13 of Set 6 | asosa
# Processing Record 14 of Set 6 | narsaq
# Processing Record 15 of Set 6 | mount isa
# Processing Record 16 of Set 6 | jaciara
# Processing Record 17 of Set 6 | banda aceh
# Processing Record 18 of Set 6 | barra do corda
# Processing Record 19 of Set 6 | port augusta
# Processing Record 20 of Set 6 | providencia
# Processing Record 21 of Set 6 | port-gentil
# Processing Record 22 of Set 6 | kaitangata
# Processing Record 23 of Set 6 | mugur-aksy
# Processing Record 24 of Set 6 | balezino
# Processing Record 25 of Set 6 | baijiantan
# Processing Record 26 of Set 6 | popondetta
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | sokoto
# Processing Record 29 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | teahupoo
# Processing Record 31 of Set 6 | chiang klang
# Processing Record 32 of Set 6 | rawson
# Processing Record 33 of Set 6 | sao mateus do sul
# Processing Record 34 of Set 6 | menongue
# Processing Record 35 of Set 6 | gimli
# Processing Record 36 of Set 6 | kahului
# Processing Record 37 of Set 6 | iranshahr
# Processing Record 38 of Set 6 | manga
# Processing Record 39 of Set 6 | marsa matruh
# Processing Record 40 of Set 6 | edd
# Processing Record 41 of Set 6 | chernyshevskiy
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | mount gambier
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | karratha
# Processing Record 47 of Set 6 | camacha
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | dharchula
# Processing Record 50 of Set 6 | lavrentiya
# Processing Record 1 of Set 7 | shestakovo
# Processing Record 2 of Set 7 | korla
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | pacifica
# Processing Record 6 of Set 7 | sinnamary
# Processing Record 7 of Set 7 | asau
# Processing Record 8 of Set 7 | xining
# Processing Record 9 of Set 7 | bontang
# Processing Record 10 of Set 7 | penzance
# Processing Record 11 of Set 7 | plettenberg bay
# Processing Record 12 of Set 7 | aluksne
# Processing Record 13 of Set 7 | kangaba
# Processing Record 14 of Set 7 | akyab
# Processing Record 15 of Set 7 | aklavik
# Processing Record 16 of Set 7 | huanren
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | velingara
# Processing Record 19 of Set 7 | cayenne
# Processing Record 20 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 7 | neiafu
# Processing Record 22 of Set 7 | mecca
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | praia da vitoria
# Processing Record 25 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 7 | saint-francois
# Processing Record 27 of Set 7 | kholbon
# Processing Record 28 of Set 7 | lata
# Processing Record 29 of Set 7 | livani
# Processing Record 30 of Set 7 | seoul
# Processing Record 31 of Set 7 | chute-aux-outardes
# Processing Record 32 of Set 7 | guozhen
# Processing Record 33 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 7 | kieta
# Processing Record 35 of Set 7 | zatyshshya
# Processing Record 36 of Set 7 | azle
# Processing Record 37 of Set 7 | urucara
# Processing Record 38 of Set 7 | bemidji
# Processing Record 39 of Set 7 | kismayo
# Processing Record 40 of Set 7 | airai
# Processing Record 41 of Set 7 | saint-pierre
# Processing Record 42 of Set 7 | shamkhal
# Processing Record 43 of Set 7 | kirensk
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | moultonborough
# Processing Record 46 of Set 7 | kiambu
# Processing Record 47 of Set 7 | lamu
# Processing Record 48 of Set 7 | avera
# Processing Record 49 of Set 7 | dalvik
# Processing Record 50 of Set 7 | sapulpa
# Processing Record 1 of Set 8 | rockhampton
# Processing Record 2 of Set 8 | lengshuitan
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | veinticinco de mayo
# Processing Record 5 of Set 8 | muravlenko
# Processing Record 6 of Set 8 | matamoros
# Processing Record 7 of Set 8 | gangapur
# Processing Record 8 of Set 8 | sosnovo-ozerskoye
# Processing Record 9 of Set 8 | bubaque
# Processing Record 10 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 8 | selishche
# Processing Record 12 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 13 of Set 8 | faanui
# Processing Record 14 of Set 8 | san patricio
# Processing Record 15 of Set 8 | merrill
# Processing Record 16 of Set 8 | laguna
# Processing Record 17 of Set 8 | luwuk
# Processing Record 18 of Set 8 | dicabisagan
# Processing Record 19 of Set 8 | murgab
# Processing Record 20 of Set 8 | inverell
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | ahipara
# Processing Record 23 of Set 8 | roma
# Processing Record 24 of Set 8 | serenje
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | sonderso
# Processing Record 27 of Set 8 | cordoba
# Processing Record 28 of Set 8 | tilichiki
# Processing Record 29 of Set 8 | pochutla
# Processing Record 30 of Set 8 | andra
# Processing Record 31 of Set 8 | mackay
# Processing Record 32 of Set 8 | nanakuli
# Processing Record 33 of Set 8 | qasigiannguit
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | da nang
# Processing Record 37 of Set 8 | jilikul
# Processing Record 38 of Set 8 | tenenkou
# Processing Record 39 of Set 8 | yar-sale
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | north branch
# Processing Record 42 of Set 8 | keskin
# Processing Record 43 of Set 8 | tres arroyos
# Processing Record 44 of Set 8 | moussoro
# Processing Record 45 of Set 8 | pavilosta
# Processing Record 46 of Set 8 | la paz
# Processing Record 47 of Set 8 | krasnoye
# Processing Record 48 of Set 8 | urubicha
# Processing Record 49 of Set 8 | tomakomai
# Processing Record 50 of Set 8 | sicuani
# Processing Record 1 of Set 9 | lensk
# Processing Record 2 of Set 9 | oksfjord
# Processing Record 3 of Set 9 | tateyama
# Processing Record 4 of Set 9 | cuiaba
# Processing Record 5 of Set 9 | camacupa
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | mabaruma
# Processing Record 8 of Set 9 | novo aripuana
# Processing Record 9 of Set 9 | orotukan
# Processing Record 10 of Set 9 | suihua
# Processing Record 11 of Set 9 | bonthe
# Processing Record 12 of Set 9 | ribeira grande
# Processing Record 13 of Set 9 | parry sound
# Processing Record 14 of Set 9 | castro
# Processing Record 15 of Set 9 | lishui
# Processing Record 16 of Set 9 | moerai
# Processing Record 17 of Set 9 | porto empedocle
# Processing Record 18 of Set 9 | tocopilla
# Processing Record 19 of Set 9 | dauriya
# Processing Record 20 of Set 9 | pocatello
# Processing Record 21 of Set 9 | shamary
# Processing Record 22 of Set 9 | matara
# Processing Record 23 of Set 9 | port hardy
# Processing Record 24 of Set 9 | saint-joseph
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | kristiinankaupunki
# Processing Record 27 of Set 9 | chuy
# Processing Record 28 of Set 9 | severo-kurilsk
# Processing Record 29 of Set 9 | lulea
# Processing Record 30 of Set 9 | bam
# Processing Record 31 of Set 9 | bermejo
# Processing Record 32 of Set 9 | mandalgovi
# Processing Record 33 of Set 9 | hurghada
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | nome
# Processing Record 36 of Set 9 | carson city
# Processing Record 37 of Set 9 | pangnirtung
# Processing Record 38 of Set 9 | liusha
# Processing Record 39 of Set 9 | tevaitoa
# Processing Record 40 of Set 9 | sayyan
# Processing Record 41 of Set 9 | puteyets
# Processing Record 42 of Set 9 | half moon bay
# Processing Record 43 of Set 9 | viedma
# Processing Record 44 of Set 9 | atasu
# Processing Record 45 of Set 9 | kajaani
# Processing Record 46 of Set 9 | hot springs
# Processing Record 47 of Set 9 | estevan
# Processing Record 48 of Set 9 | ponta delgada
# Processing Record 49 of Set 9 | hirara
# Processing Record 50 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 10 | salekhard
# Processing Record 2 of Set 10 | manokwari
# Processing Record 3 of Set 10 | cradock
# Processing Record 4 of Set 10 | sibolga
# Processing Record 5 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 6 of Set 10 | roebourne
# Processing Record 7 of Set 10 | yumen
# Processing Record 8 of Set 10 | belyy yar
# Processing Record 9 of Set 10 | gizo
# Processing Record 10 of Set 10 | quatre cocos
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | kaeo
# Processing Record 13 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 14 of Set 10 | kruisfontein
# Processing Record 15 of Set 10 | pevek
# Processing Record 16 of Set 10 | dali
# Processing Record 17 of Set 10 | tigil
# Processing Record 18 of Set 10 | inderka
# Processing Record 19 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 10 | montes claros
# Processing Record 21 of Set 10 | oriximina
# Processing Record 22 of Set 10 | elmira
# Processing Record 23 of Set 10 | oban
# Processing Record 24 of Set 10 | elliot
# Processing Record 25 of Set 10 | anloga
# Processing Record 26 of Set 10 | collie
# Processing Record 27 of Set 10 | ambon
# Processing Record 28 of Set 10 | morros
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | nishihara
# Processing Record 31 of Set 10 | zyryanka
# Processing Record 32 of Set 10 | windhoek
# Processing Record 33 of Set 10 | nouakchott
# Processing Record 34 of Set 10 | port hedland
# Processing Record 35 of Set 10 | bilibino
# Processing Record 36 of Set 10 | perivolion
# Processing Record 37 of Set 10 | san juan de los morros
# Processing Record 38 of Set 10 | kapuskasing
# Processing Record 39 of Set 10 | abu kamal
# Processing Record 40 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 10 | pesochnoye
# Processing Record 42 of Set 10 | zarand
# Processing Record 43 of Set 10 | broome
# Processing Record 44 of Set 10 | muli
# Processing Record 45 of Set 10 | alenquer
# Processing Record 46 of Set 10 | iqaluit
# Processing Record 47 of Set 10 | tiarei
# Processing Record 48 of Set 10 | svetlogorsk
# Processing Record 49 of Set 10 | lompoc
# Processing Record 50 of Set 10 | valley city
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | turka
# Processing Record 3 of Set 11 | burica
# City not found. Skipping...
# Processing Record 4 of Set 11 | noyabrsk
# Processing Record 5 of Set 11 | sikasso
# Processing Record 6 of Set 11 | gemena
# Processing Record 7 of Set 11 | nanortalik
# Processing Record 8 of Set 11 | shelburne
# Processing Record 9 of Set 11 | salamanca
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | lazaro cardenas
# Processing Record 12 of Set 11 | bunda
# Processing Record 13 of Set 11 | morondava
# Processing Record 14 of Set 11 | san luis
# Processing Record 15 of Set 11 | baykit
# Processing Record 16 of Set 11 | salaya
# Processing Record 17 of Set 11 | noumea
# Processing Record 18 of Set 11 | tacna
# Processing Record 19 of Set 11 | maldonado
# Processing Record 20 of Set 11 | miraflores
# Processing Record 21 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 11 | salinas
# Processing Record 24 of Set 11 | denpasar
# Processing Record 25 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 26 of Set 11 | ust-kuyga
# Processing Record 27 of Set 11 | misratah
# Processing Record 28 of Set 11 | kikwit
# Processing Record 29 of Set 11 | itoman
# Processing Record 30 of Set 11 | abha
# Processing Record 31 of Set 11 | havre-saint-pierre
# Processing Record 32 of Set 11 | teknaf
# Processing Record 33 of Set 11 | fairbanks
# Processing Record 34 of Set 11 | barcelos
# Processing Record 35 of Set 11 | hambantota
# Processing Record 36 of Set 11 | lahaina
# Processing Record 37 of Set 11 | batagay
# Processing Record 38 of Set 11 | xinzhou
# Processing Record 39 of Set 11 | ankang
# Processing Record 40 of Set 11 | christchurch
# Processing Record 41 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 11 | zlitan
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | gariaband
# Processing Record 45 of Set 11 | sisimiut
# Processing Record 46 of Set 11 | karpogory
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | caravelas
# Processing Record 49 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 50 of Set 11 | jalu
# Processing Record 1 of Set 12 | shirvan
# Processing Record 2 of Set 12 | dakar
# Processing Record 3 of Set 12 | ondjiva
# Processing Record 4 of Set 12 | ust-tsilma
# Processing Record 5 of Set 12 | petrolina
# Processing Record 6 of Set 12 | lircay
# Processing Record 7 of Set 12 | ocean city
# Processing Record 8 of Set 12 | kamaishi
# Processing Record 9 of Set 12 | beroroha
# Processing Record 10 of Set 12 | boksitogorsk
# Processing Record 11 of Set 12 | fomboni
# Processing Record 12 of Set 12 | phangnga
# Processing Record 13 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 12 | salalah
# Processing Record 15 of Set 12 | athgarh
# City not found. Skipping...
# Processing Record 16 of Set 12 | dawlatabad
# Processing Record 17 of Set 12 | kloulklubed
# Processing Record 18 of Set 12 | binabalian
# Processing Record 19 of Set 12 | paita
# Processing Record 20 of Set 12 | arman
# Processing Record 21 of Set 12 | wanxian
# Processing Record 22 of Set 12 | palora
# Processing Record 23 of Set 12 | imperia
# Processing Record 24 of Set 12 | arica
# Processing Record 25 of Set 12 | rocha
# Processing Record 26 of Set 12 | lekoni
# Processing Record 27 of Set 12 | anacortes
# Processing Record 28 of Set 12 | bacungan
# Processing Record 29 of Set 12 | evensk
# Processing Record 30 of Set 12 | qaqortoq
# Processing Record 31 of Set 12 | madison
# Processing Record 32 of Set 12 | waiuku
# Processing Record 33 of Set 12 | shubarshi
# Processing Record 34 of Set 12 | inirida
# Processing Record 35 of Set 12 | mossendjo
# Processing Record 36 of Set 12 | xichang
# Processing Record 37 of Set 12 | atar
# Processing Record 38 of Set 12 | bamboo
# Processing Record 39 of Set 12 | yulara
# Processing Record 40 of Set 12 | mana
# Processing Record 41 of Set 12 | owatonna
# Processing Record 42 of Set 12 | gasa
# Processing Record 43 of Set 12 | tangi
# Processing Record 44 of Set 12 | sehithwa
# Processing Record 45 of Set 12 | sao raimundo nonato
# Processing Record 46 of Set 12 | mehamn
# Processing Record 47 of Set 12 | farkhor
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | westport
# Processing Record 50 of Set 12 | nhulunbuy
# Processing Record 1 of Set 13 | tongchuan
# Processing Record 2 of Set 13 | mezhova
# Processing Record 3 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 13 | san antonio
# Processing Record 5 of Set 13 | mindelo
# Processing Record 6 of Set 13 | byron bay
# Processing Record 7 of Set 13 | sigulda
# Processing Record 8 of Set 13 | statesville
# Processing Record 9 of Set 13 | vicosa do ceara
# Processing Record 10 of Set 13 | taksimo
# Processing Record 11 of Set 13 | wenzhou
# Processing Record 12 of Set 13 | kontagora
# Processing Record 13 of Set 13 | jiazi
# Processing Record 14 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 16 of Set 13 | kyabram
# Processing Record 17 of Set 13 | totness
# Processing Record 18 of Set 13 | lugano
# Processing Record 19 of Set 13 | snasa
# Processing Record 20 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 13 | jacksonville
# Processing Record 23 of Set 13 | berck
# Processing Record 24 of Set 13 | san cristobal
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | merauke
# Processing Record 27 of Set 13 | saint-denis
# Processing Record 28 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | verkhoyansk
# Processing Record 30 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 13 | hofn
# Processing Record 32 of Set 13 | neuquen
# Processing Record 33 of Set 13 | shiyan
# Processing Record 34 of Set 13 | ahuimanu
# Processing Record 35 of Set 13 | yerkoy
# Processing Record 36 of Set 13 | ciudad bolivar
# Processing Record 37 of Set 13 | matagami
# Processing Record 38 of Set 13 | riyadh
# Processing Record 39 of Set 13 | oktyabrskiy
# Processing Record 40 of Set 13 | thai binh
# Processing Record 41 of Set 13 | san jose
# Processing Record 42 of Set 13 | whitehorse
# Processing Record 43 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 44 of Set 13 | almeirim
# Processing Record 45 of Set 13 | varadero
# Processing Record 46 of Set 13 | opuwo
# Processing Record 47 of Set 13 | dzhebariki-khaya
# Processing Record 48 of Set 13 | barre
# Processing Record 49 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 13 | leningradskiy
# Processing Record 1 of Set 14 | jaru
# Processing Record 2 of Set 14 | emerald
# Processing Record 3 of Set 14 | spirit river
# Processing Record 4 of Set 14 | gushikawa
# Processing Record 5 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 6 of Set 14 | belaya gora
# Processing Record 7 of Set 14 | aleksandrov gay
# Processing Record 8 of Set 14 | eureka
# Processing Record 9 of Set 14 | sidi ali
# Processing Record 10 of Set 14 | san buenaventura
# Processing Record 11 of Set 14 | kolokani
# Processing Record 12 of Set 14 | manta
# Processing Record 13 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 14 | kose
# Processing Record 15 of Set 14 | muros
# Processing Record 16 of Set 14 | eloy
# Processing Record 17 of Set 14 | haiger
# Processing Record 18 of Set 14 | ushtobe
# Processing Record 19 of Set 14 | chapais
# Processing Record 20 of Set 14 | begoro
# Processing Record 21 of Set 14 | urumqi
# Processing Record 22 of Set 14 | padang
# Processing Record 23 of Set 14 | leshukonskoye
# Processing Record 24 of Set 14 | altamont
# Processing Record 25 of Set 14 | union city
# Processing Record 26 of Set 14 | morant bay
# Processing Record 27 of Set 14 | tombouctou
# Processing Record 28 of Set 14 | bestobe
# Processing Record 29 of Set 14 | columbus
# Processing Record 30 of Set 14 | port blair
# Processing Record 31 of Set 14 | zeya
# Processing Record 32 of Set 14 | churapcha
# Processing Record 33 of Set 14 | namanga
# Processing Record 34 of Set 14 | andapa
# Processing Record 35 of Set 14 | bolshaya sosnova
# Processing Record 36 of Set 14 | chissamba
# Processing Record 37 of Set 14 | minas de barroteran
# Processing Record 38 of Set 14 | caborca
# Processing Record 39 of Set 14 | manono
# Processing Record 40 of Set 14 | sabalgarh
# Processing Record 41 of Set 14 | palmer
# Processing Record 42 of Set 14 | hailey
# Processing Record 43 of Set 14 | poum
# Processing Record 44 of Set 14 | kilindoni
# Processing Record 45 of Set 14 | itarema
# Processing Record 46 of Set 14 | yarada
# Processing Record 47 of Set 14 | berlevag
# Processing Record 48 of Set 14 | puerto escondido
# Processing Record 49 of Set 14 | ust-nera
# Processing Record 50 of Set 14 | varkkallai
# Processing Record 1 of Set 15 | atambua
# Processing Record 2 of Set 15 | sao fidelis
# Processing Record 3 of Set 15 | ossora
# Processing Record 4 of Set 15 | honningsvag
# Processing Record 5 of Set 15 | russell
# Processing Record 6 of Set 15 | pasni
# Processing Record 7 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 8 of Set 15 | varzea grande
# Processing Record 9 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 15 | coquimbo
# Processing Record 11 of Set 15 | bud
# Processing Record 12 of Set 15 | victor harbor
# Processing Record 13 of Set 15 | marquette
# Processing Record 14 of Set 15 | aguimes
# Processing Record 15 of Set 15 | linxia
# Processing Record 16 of Set 15 | witu
# Processing Record 17 of Set 15 | okhotsk
# Processing Record 18 of Set 15 | tingi
# Processing Record 19 of Set 15 | chestermere
# Processing Record 20 of Set 15 | abhar
# Processing Record 21 of Set 15 | shetpe
# Processing Record 22 of Set 15 | coahuayana
# Processing Record 23 of Set 15 | pathein
# Processing Record 24 of Set 15 | onega
# Processing Record 25 of Set 15 | imbituba
# Processing Record 26 of Set 15 | samarinda
# Processing Record 27 of Set 15 | quelimane
# Processing Record 28 of Set 15 | poplar bluff
# Processing Record 29 of Set 15 | santa fe
# Processing Record 30 of Set 15 | alpena
# Processing Record 31 of Set 15 | zhanaozen
# Processing Record 32 of Set 15 | sangar
# Processing Record 33 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 15 | coruripe
# Processing Record 35 of Set 15 | nemuro
# Processing Record 36 of Set 15 | gunjur
# Processing Record 37 of Set 15 | stawell
# Processing Record 38 of Set 15 | wanning
# Processing Record 39 of Set 15 | concarneau
# Processing Record 40 of Set 15 | abu samrah
# Processing Record 41 of Set 15 | bull savanna
# Processing Record 42 of Set 15 | inndyr
# Processing Record 43 of Set 15 | molepolole
# Processing Record 44 of Set 15 | ambilobe
# Processing Record 45 of Set 15 | cairns
# Processing Record 46 of Set 15 | kouqian
# Processing Record 47 of Set 15 | nha trang
# Processing Record 48 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 15 | north bend
# Processing Record 50 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 1 of Set 16 | karakol
# Processing Record 2 of Set 16 | kasongo
# Processing Record 3 of Set 16 | ishigaki
# Processing Record 4 of Set 16 | jawa
# Processing Record 5 of Set 16 | kalmunai
# Processing Record 6 of Set 16 | the valley
# Processing Record 7 of Set 16 | vagur
# Processing Record 8 of Set 16 | kokstad
# Processing Record 9 of Set 16 | kishi
# Processing Record 10 of Set 16 | rio grande
# Processing Record 11 of Set 16 | san carlos de bariloche
# Processing Record 12 of Set 16 | kota bahru
# Processing Record 13 of Set 16 | placido de castro
# Processing Record 14 of Set 16 | tynda
# Processing Record 15 of Set 16 | leczna
# Processing Record 16 of Set 16 | howard springs
# Processing Record 17 of Set 16 | bakel
# Processing Record 18 of Set 16 | awjilah
# Processing Record 19 of Set 16 | sabang
# Processing Record 20 of Set 16 | shelton
# Processing Record 21 of Set 16 | tommot
# Processing Record 22 of Set 16 | megion
# Processing Record 23 of Set 16 | hoquiam
# Processing Record 24 of Set 16 | havoysund
# Processing Record 25 of Set 16 | nancha
# Processing Record 26 of Set 16 | craig
# Processing Record 27 of Set 16 | atmakur
# Processing Record 28 of Set 16 | worpswede
# Processing Record 29 of Set 16 | poso
# Processing Record 30 of Set 16 | tazovskiy
# Processing Record 31 of Set 16 | hami
# Processing Record 32 of Set 16 | pangai
# Processing Record 33 of Set 16 | odesskoye
# Processing Record 34 of Set 16 | saquena
# Processing Record 35 of Set 16 | khani
# Processing Record 36 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 16 | varzea alegre
# Processing Record 38 of Set 16 | nagua
# Processing Record 39 of Set 16 | flin flon
# Processing Record 40 of Set 16 | namatanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 734

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq      GL  65.6145  -37.6368     42.96        95         100
# 1         Rikitea      PF -23.1203 -134.9692     71.22        64          55
# 2          Tiznit      MA  29.5833   -9.5000     76.28        54          20
# 3      Butaritari      KI   3.0707  172.7902     81.93        76          11
# 4  Port Elizabeth      ZA -33.9180   25.5701     60.31        91          75
# 5     Hvide Sande      DK  56.0045    8.1294     55.09        67          29
# 6      Santa Cruz      BO -17.8000  -63.1667     84.25        54           3
# 7      Vila Velha      BR -20.3297  -40.2925     73.35        68          75
# 8       Busselton      AU -33.6500  115.3333     54.32        78         100
# 9        Khatanga      RU  71.9667  102.5000     26.65        80           9
#
#    Wind Speed Current Description
# 0       17.98       moderate rain
# 1       17.25       broken clouds
# 2       11.36          few clouds
# 3       13.42          few clouds
# 4       12.66          light rain
# 5       23.31    scattered clouds
# 6       17.27           clear sky
# 7       14.00       broken clouds
# 8        8.72     overcast clouds
# 9        8.77           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
